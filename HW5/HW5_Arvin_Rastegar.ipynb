# %% [markdown]
# #HW5: Autoencoders
#
# In this homework, we will explore how to develop a simple Autoencoder. As a dataset, we will use the MNIST dataset. It contains handwritten digits images.
# In the first part, we will learn how to develop a simple shallow autoencoder, then we will develop a deep version. Next, we will experiment with the application of autoencoder on denoising data task (denoising-autoencoder). Finally, we will apply this model to sequential domains, considering the IMDB dataset, already used in HW4.

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ###Load Dataset
# We load the MNIST dataset, using tf.keras.datasets. The dataset contains 60,000 training images and 10,000 testing images.
# The value of each pixel is between 0 and 255, and it represents a point of an image of size 28 x 28. We will normalize all values between 0 and 1, and we will flatten the 28x28 images into vectors of size 784.
# Finally, since no validation set is defined, we split the test set in a validation set and a new test set.

# %%
(x_train, _), (x_test, _) = tf.keras.datasets.mnist.load_data()

x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255


x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

x_valid = x_train[:10000]
x_train = x_train[10000:]

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.1: Singular Value Decomposition
#
# Principal component analysis (PCA) and singular value decomposition (SVD) are both classical linear dimensionality reduction methods that attempt to find linear combinations of features in the original high dimensional data matrix to construct a meaningful representation of the dataset.
# In this first part of the HW, we will focus our attention on SVD decomposition, a numerical stable method. Given a matrix X, the SVD decomposes it into the product of two unitary matrices V and U and a rectangular diagonal matrix of singular values S:
#
# $$ X=V \cdot S \cdot U^T.$$
#
# SVD is already implemented in NumPy as np.linalg.svd. In our case, the X matrix will represent the training set, where each row is a sample (therefore the number of columns will be the number of input features).
#
# Note that, the X matrix in our case will have a huge number of rows (we have 50000 input samples) and only 784 columns. Therefore to optime the memory consumption, we can compute the SVD of the covariance matrix. An interesting property of the SVD is that we compute the decomposition of the covariance matrix $C= X^T \cdot X$, and we will obtain the following decomposition:
#
# $$ C= U \cdot S^2 \cdot U^T$$
#
# Since we need just the matrix U to compute the compressed version of our data, this method will be very convenient. If you are using the collab free plan, the quantity of available ram is not sufficient to compute the SVD of X, therefore computing the SVD of the covariance matrix turns out to be the best solution.

# %%
def svd_k(X, k):
  # Compute covariance matrix
  C = np.dot(X.T, X)
  # SVD decomposition
  U, s_sqr, U_T = np.linalg.svd(C, full_matrices=False)
  # Limit the number columns of U to k
  U_k=U[:,:k]
  return U_k

# %% [markdown]
# Let's define the ENCODING_DIM, that will be the size of the compressed version of input data. And compute the compressed version of the training set and the test set.
#
# **[TO COMPLETE]**: What happens varying the ENCODING_DIM? test  and discuss the results in a new cell after the following one.

# %%
ENCODING_DIM = 120

U_k=svd_k(x_train, ENCODING_DIM)

x_training_pca = np.dot(x_train, U_k)
x_test_pca = np.dot(x_test, U_k)

# %% [markdown]
# Reconstruct the input and check how much information was lost due to the compression, by computing the mean squared error between the original input and the reconstruction, and by plotting the reconstructed images.

# %% [markdown]
# **What happens to vary the ENCODING_DIM?**
#
# When we test the encoding dimension and change it to higher values, we see that training error decreases, and the test error converges toward the training error where, with lower encoding dimensions, we see that both errors increase and they start to have more different results.

# %%
x_training_reco= np.dot(x_training_pca, U_k.T)
x_test_reco= np.dot(x_test_pca, U_k.T)

# %%
accuracy_train = ((x_train - x_training_reco)**2).mean()
accuracy_test = ((x_test - x_test_reco)**2).mean()

print("training mse: %.5f" % ( accuracy_train))
print("test mse: %.5f" % ( accuracy_test))
# Out:
# training mse: 0.00464
# test mse: 0.00455

# %%
def plot_img(n, input_data, decoded_imgs):
  plt.figure(figsize=(20, 4))
  for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(input_data[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
  plt.show()

# %% [markdown]
# Let's check how well the input can be reconstructed by printing a few of the input images and the corresponding reconstructions. Obviously, all these evaluations have to be done on the test set.
#
# The first row of shown images corresponds to input data, while the second one contains the reconstructions.

# %%
plot_img(10, x_test, x_test_reco)

# %% [markdown]
# ## [TO COMPLETE] Exercise 5.2: Shallow Linear Autoencoder
# Let's define a model that consists of a single fully-connected neural layer. The hidden layer and the output layer act as the encoder and the decoder, respectively. Differently than the previous homework, instead of using Keras.Sequential(), we define the various part of the model (encoder and decoder) separately and then we create the final model.
#
# **[TO COMPLETE]** check the results and compare them versus the results obtained with the SVD. Add a cell  at the end of this section (after the result of the linear autoencoder) where you give an explanation of the relation between the results obtained  by the shallow linear autoencoder and the ones obtained by the SVD decomposition.

# %%
ENCODING_DIM = 120

input_img = tf.keras.layers.Input(shape=(784,))
#Define the encoder...
encoded = tf.keras.layers.Dense(ENCODING_DIM, activation='linear')(input_img)

#...and the decoder...
decoded = tf.keras.layers.Dense(784, activation='linear')(encoded)

#and finally the autoencoder
autoencoder = tf.keras.models.Model(input_img, decoded)

# In order to visualize the learned encoding, define a model that computes the 
# two parts separately.
encoder = tf.keras.models.Model(input_img, encoded)
encoded_input = tf.keras.layers.Input(shape=(ENCODING_DIM,))
decoder_layer = autoencoder.layers[-1]
decoder = tf.keras.models.Model(encoded_input, decoder_layer(encoded_input))

#Finally, let's call the compile method
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), loss='mse')

# %% [markdown]
# Print the model summary.

# %%
autoencoder.summary()
# Out:
# Model: "model_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_19 (InputLayer)        [(None, 784)]             0
# _________________________________________________________________
# dense_33 (Dense)             (None, 120)               94200
# _________________________________________________________________
# dense_34 (Dense)             (None, 784)               94864
# =================================================================
# Total params: 189,064
# Trainable params: 189,064
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model.

# %%
history = autoencoder.fit(x_train, x_train, epochs=15, batch_size=512, shuffle=True, validation_data=(x_valid, x_valid))
# Out:
# Epoch 1/15
# 98/98 [==============================] - 1s 5ms/step - loss: 0.0821 - val_loss: 0.0142
# Epoch 2/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0128 - val_loss: 0.0087
# Epoch 3/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0082 - val_loss: 0.0068
# Epoch 4/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 5/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0060
# Epoch 6/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 7/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 8/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0050
# Epoch 9/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0052
# Epoch 10/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0049
# Epoch 11/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0050
# Epoch 12/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0049 - val_loss: 0.0057
# Epoch 13/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0048
# Epoch 14/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0064
# Epoch 15/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 0.0048

# %% [markdown]
# Comparing Results between shallow auto encoder and SVD
#
# Shallow auto encoder with higher encoding dimension has higher training time.
# We have less error in both validation and training in svd than our neural layer, unless we lower the encoding dimension to very low numbers.
# Our conclusion however remains the same that SVDs perform faster and better than shallow auto encoders.
#
# ---
#
#
# **Explanation of the relation between the results obtained by the shallow linear autoencoder and the ones obtained by the SVD decomposition**
#
# In principle, both models follow the same procedure, and they are doing the same principal component analysis. Encoding the input in a lower dimension and decoding it again in the original dimension. Linear auto encoder only does this by a neural network rather than a conventional matrix multiplication.

# %% [markdown]
# Plot the loss and the accuracy curves on the validation set, and the accuracy on the test set.

# %%
def plot_loss(history):
  plt.figure(figsize=(10,6))
  plt.plot(history.epoch,history.history['loss'])
  plt.plot(history.epoch,history.history['val_loss'])
  plt.title('loss')

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test, x_test, verbose=2)
print("test mse: %.5f" % (scores))
# Out:
# 313/313 - 0s - loss: 0.0048
# test mse: 0.00478

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

plot_img(10, x_test, decoded_imgs)

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.3: Shallow non-linear autoencoders
#
# **[TO COMPLETE]** replicate the code of Exercise 5.1 but in this case, instead of using linear activation functions use  non-linear ones. Choose the most appropriate non-linear function, and motivate your choice. Then discuss the results in relation to those obtained in Exercise 5.1. (Insert your code and  theoretical discussion into  cells immediately below this one.)

# %% [markdown]
# **Non-linear activation functions:**
#
# We use a for loop to search through the best non-linear activation functions. The activation function list we use is ['tanh', 'sigmoid', 'relu', 'selu', 'elu']. All of them give acceptable results except tanh, and between them, we see that sigmoid is performing slightly better than others.
# Sigmoid function even gives better results compared to the linear activation function.
# Whereas tanh loss is almost double the sigmoid function.

# %%
ENCODING_DIM = 120

input_img = tf.keras.layers.Input(shape=(784,))
#Define the encoder...
encoded = tf.keras.layers.Dense(ENCODING_DIM, activation='sigmoid')(input_img)

#...and the decoder...
decoded = tf.keras.layers.Dense(784, activation='sigmoid')(encoded)

#and finally the autoencoder
autoencoder = tf.keras.models.Model(input_img, decoded)

# In order to visualize the learned encoding, define a model that computes the 
# two parts separately.
encoder = tf.keras.models.Model(input_img, encoded)
encoded_input = tf.keras.layers.Input(shape=(ENCODING_DIM,))
decoder_layer = autoencoder.layers[-1]
decoder = tf.keras.models.Model(encoded_input, decoder_layer(encoded_input))

#Finally, let's call the compile method
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), loss='mse')
autoencoder.summary()
history = autoencoder.fit(x_train, x_train, epochs=15, batch_size=512, shuffle=True, validation_data=(x_valid, x_valid))
# Out:
# Model: "model_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_21 (InputLayer)        [(None, 784)]             0
# _________________________________________________________________
# dense_35 (Dense)             (None, 120)               94200
# _________________________________________________________________
# dense_36 (Dense)             (None, 784)               94864
# =================================================================
# Total params: 189,064
# Trainable params: 189,064
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 98/98 [==============================] - 1s 5ms/step - loss: 0.0756 - val_loss: 0.0360
# Epoch 2/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0325 - val_loss: 0.0232
# Epoch 3/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0215 - val_loss: 0.0165
# Epoch 4/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0156 - val_loss: 0.0127
# Epoch 5/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0122 - val_loss: 0.0105
# Epoch 6/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0101 - val_loss: 0.0089
# Epoch 7/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0086 - val_loss: 0.0078
# Epoch 8/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0076 - val_loss: 0.0069
# Epoch 9/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 0.0062
# Epoch 10/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0061 - val_loss: 0.0058
# Epoch 11/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0054
# Epoch 12/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 13/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 14/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 0.0045
# Epoch 15/15
# 98/98 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.0044

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test, x_test, verbose=2)
print("test mse: %.5f" % (scores))

encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

plot_img(10, x_test, decoded_imgs)
# Out:
# 313/313 - 0s - loss: 0.0043
# test mse: 0.00429

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.4: Deep Autoencoder
# **[TO COMPLETE]**: Define a deep version of the Autoeancoder defined above. The autoencoder has to use at least 5 layers. The model will use $n$ layers for encoding, and n-1 for decoding. The layers sizes of the encoding part decrease at each layer (i.e. 784->128->64, where 64 is the encoding dim). The decoding part layers dimensions progression turns out to be mirrored (i.e 128->784, the resulting overall structure recalls an hourglass).
# Similarly than what we did above, print the model summary, the loss curves during the training, the achieved loss on the test set, and some input images with the corresponding decoding.

# %%
# Here relu activation works as the best activation function with the lowest loss,
# and we use softmax at the output layer to classify the correct class.

input_img = tf.keras.layers.Input(shape=(784,))

encoded = tf.keras.layers.Dense(128, activation='relu')(input_img)
encoded = tf.keras.layers.Dense(64, activation='relu')(encoded)

decoded = tf.keras.layers.Dense(128, activation='relu')(encoded)
decoded = tf.keras.layers.Dense(784, activation='sigmoid')(decoded)

autoencoder = tf.keras.models.Model(input_img, decoded)


autoencoder.compile(optimizer='adam', loss='mse')

# %%
autoencoder.summary()
# Out:
# Model: "model_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_23 (InputLayer)        [(None, 784)]             0
# _________________________________________________________________
# dense_37 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_39 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_40 (Dense)             (None, 784)               101136
# =================================================================
# Total params: 218,192
# Trainable params: 218,192
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = autoencoder.fit(x_train, x_train, epochs= 15, batch_size= 32, shuffle=True, validation_data=(x_valid, x_valid))
# Out:
# Epoch 1/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.0445 - val_loss: 0.0125
# Epoch 2/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.0115 - val_loss: 0.0091
# Epoch 3/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.0088 - val_loss: 0.0075
# Epoch 4/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.0074 - val_loss: 0.0069
# Epoch 5/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.0067 - val_loss: 0.0064
# Epoch 6/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.0062 - val_loss: 0.0058
# Epoch 7/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.0058 - val_loss: 0.0056
# Epoch 8/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.0055 - val_loss: 0.0055
# Epoch 9/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.0053 - val_loss: 0.0052
# Epoch 10/15
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 11/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 12/15
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 13/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 14/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.0048 - val_loss: 0.0050
# Epoch 15/15
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.0048 - val_loss: 0.0048

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test, x_test, verbose=2)
print("test mse: %.5f" % (scores))
# Out:
# 313/313 - 0s - loss: 0.0047
# test mse: 0.00471

# %%
decoded_imgs = autoencoder.predict(x_test)

plot_img(10, x_test, decoded_imgs)

# %% [markdown]
# ## [TO COMPLETE] Exercise 5.5: Denoising Autoencoder
#
# Let's now use a shallow autoencoder to denoise the input data.
# Firstly, define a noisy input by adding some noise to our input data. We define a noise factor that can be used to modify the amount of noise to add to the input data. Check how much it influences the denoising capability of the autoencoder.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

x_valid, y_valid = x_train[:10000],y_train[:10000]
x_train, y_train = x_train[10000:],y_train[10000:]

noise_factor = 0.3

x_train_noisy = x_train + noise_factor + np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor + np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
x_valid_noisy = x_valid + noise_factor + np.random.normal(loc=0.0, scale=1.0, size=x_valid.shape)


x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)
x_valid_noisy = np.clip(x_valid_noisy, 0., 1.)

# %% [markdown]
# Plot some noisy inputs.

# %%
# here's what the noisy digits look like
n = 10
plt.figure(figsize=(20, 2))
for i in range(n):
    ax = plt.subplot(1, n, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# **[TO COMPLETE]** Define a shallow autoencoder able to compute a de-noised version of the input (obtained by unsing a noise_factor >= 0.3).

# %%
#[TO COMPLETE]
input_img = tf.keras.layers.Input(shape=(784,))
#Define the encoder...
encoded = tf.keras.layers.Dense(256, activation='sigmoid')(input_img)
#...and the decoder...
decoded = tf.keras.layers.Dense(784, activation='sigmoid')(encoded)

autoencoder = tf.keras.models.Model(input_img, decoded)

autoencoder.compile(optimizer='adam', loss='binary_crossentropy') #[TO COMPLETE]

# %%
autoencoder.summary()
# Out:
# Model: "model_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_24 (InputLayer)        [(None, 784)]             0
# _________________________________________________________________
# dense_41 (Dense)             (None, 256)               200960
# _________________________________________________________________
# dense_42 (Dense)             (None, 784)               201488
# =================================================================
# Total params: 402,448
# Trainable params: 402,448
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **[TO COMPLETE]** Train the model by passing the noisy input and the clean target.

# %%
history = autoencoder.fit(x_train_noisy, x_train, epochs=15, batch_size=32, shuffle=True, validation_data=(x_valid, x_valid))#[TO COMPLETE]
# Out:
# Epoch 1/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.2568 - val_loss: 0.1997
# Epoch 2/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.1892 - val_loss: 0.1861
# Epoch 3/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.1743 - val_loss: 0.1818
# Epoch 4/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.1678 - val_loss: 0.1728
# Epoch 5/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.1645 - val_loss: 0.1739
# Epoch 6/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.1618 - val_loss: 0.1683
# Epoch 7/15
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.1602 - val_loss: 0.1665
# Epoch 8/15
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.1588 - val_loss: 0.1585
# Epoch 9/15
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.1574 - val_loss: 0.1555
# Epoch 10/15
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.1555 - val_loss: 0.1508
# Epoch 11/15
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.1551 - val_loss: 0.1473
# Epoch 12/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.1539 - val_loss: 0.1416
# Epoch 13/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.1529 - val_loss: 0.1362
# Epoch 14/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.1523 - val_loss: 0.1327
# Epoch 15/15
# 1563/1563 [==============================] - 4s 2ms/step - loss: 0.1512 - val_loss: 0.1301

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test_noisy, x_test, verbose=2)
print("test mse: %.5f" % (scores))
# Out:
# 313/313 - 0s - loss: 0.1634
# test mse: 0.16343

# %% [markdown]
# **[TO COMPLETE]** Check the result by plotting some input images and the corresponding denoised outputs.

# %%
decoded_imgs = autoencoder.predict(x_test_noisy)

plot_img(10, x_test_noisy, decoded_imgs)

# %% [markdown]
# ## Exercise 5.6: Linear Autoencoder for sequences
#
# Let's define a linear autoencoder for sequences. In this case, as dataset, we will use the IMDB dataset (already presented in HW4). To have a model that can be trained and tested in a reasonable time (and that works also with the memory limitation that we have in Colab), we will limit the number of training samples and test samples.

# %%
num_words = 100
(X_train, _), (X_test, _) = keras.datasets.imdb.load_data(num_words=num_words)

X_train=X_train[:10000]

(X_valid, X_test) = X_test[:1250], X_test[-1250:]

word_index = keras.datasets.imdb.get_word_index()

reverse_index = {word_id + 3: word for word, word_id in word_index.items()}
reverse_index[0] = "<pad>" # padding
reverse_index[1] = "<sos>" # start of sequence
reverse_index[2] = "<oov>" # out-of-vocabulary
reverse_index[3] = "<unk>" # unknown

def decode_review(word_ids):
    return " ".join([reverse_index.get(word_id, "<err>") for word_id in word_ids])


maxlen = 90
X_train_trim = keras.preprocessing.sequence.pad_sequences(X_train, maxlen=maxlen)
X_test_trim = keras.preprocessing.sequence.pad_sequences(X_test, maxlen=maxlen)
X_valid_trim = keras.preprocessing.sequence.pad_sequences(X_valid, maxlen=maxlen)
# Out:
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:159: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %% [markdown]
# In this case, we want to use as input/target a one-hot representation for each word. To convert the index representation provided by IMDB dataset loader we use the to_categorical method to transform them in the corresponding one hot representation.

# %%
from keras.utils import to_categorical


X_train_one_hot=to_categorical(X_train_trim)
X_test_one_hot=to_categorical(X_test_trim)
X_valid_one_hot=to_categorical(X_valid_trim)

# %% [markdown]
# Define a linear shallow autoencoder for sequences. The structure will be similar to the model defined in Exercise 5.2, while the used encoding layer is defined by using tf.keras.layers.SimpleRNN. Note that it uses linear activations. The decoding layer exploits [tf.keras.layers.TimeDistributed](https://www.tensorflow.org/api_docs/python/tf/keras/layers/TimeDistributed) that allows using the same dense cell at each time step of the sequence.

# %%
inputs = tf.keras.layers.Input(shape=(maxlen, num_words))
encoded = tf.keras.layers.SimpleRNN(50, return_sequences=True, activation='linear')(inputs)

decoded = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(num_words, activation='linear'))(encoded)

sequence_autoencoder = tf.keras.models.Model(inputs, decoded)
encoder = tf.keras.models.Model(inputs, encoded)

sequence_autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=["CategoricalAccuracy"])

sequence_autoencoder.summary()
# Out:
# Model: "model_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_25 (InputLayer)        [(None, 90, 100)]         0
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 90, 50)            7550
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 90, 100)           5100
# =================================================================
# Total params: 12,650
# Trainable params: 12,650
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = sequence_autoencoder.fit(X_train_one_hot, X_train_one_hot, epochs=50, batch_size=128, shuffle=True, validation_data=(X_valid_one_hot, X_valid_one_hot))
# Out:
# Epoch 1/50
# 79/79 [==============================] - 5s 57ms/step - loss: 0.2636 - categorical_accuracy: 0.0679 - val_loss: 0.0747 - val_categorical_accuracy: 0.4237
# Epoch 2/50
# 79/79 [==============================] - 4s 54ms/step - loss: 0.0659 - categorical_accuracy: 0.4682 - val_loss: 0.0521 - val_categorical_accuracy: 0.5022
# Epoch 3/50
# 79/79 [==============================] - 4s 53ms/step - loss: 0.0485 - categorical_accuracy: 0.5285 - val_loss: 0.0417 - val_categorical_accuracy: 0.5748
# Epoch 4/50
# 79/79 [==============================] - 4s 53ms/step - loss: 0.0388 - categorical_accuracy: 0.5833 - val_loss: 0.0353 - val_categorical_accuracy: 0.5907
# Epoch 5/50
# 79/79 [==============================] - 4s 54ms/step - loss: 0.0350 - categorical_accuracy: 0.6428 - val_loss: 0.0306 - val_categorical_accuracy: 0.6977
# Epoch 6/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0294 - categorical_accuracy: 0.6833 - val_loss: 0.0285 - val_categorical_accuracy: 0.6609
# Epoch 7/50
# 79/79 [==============================] - 4s 56ms/step - loss: 0.0265 - categorical_accuracy: 0.7002 - val_loss: 0.0236 - val_categorical_accuracy: 0.7421
# Epoch 8/50
# 79/79 [==============================] - 4s 54ms/step - loss: 0.0224 - categorical_accuracy: 0.7581 - val_loss: 0.0206 - val_categorical_accuracy: 0.7441
# Epoch 9/50
# 79/79 [==============================] - 4s 53ms/step - loss: 0.0196 - categorical_accuracy: 0.7507 - val_loss: 0.0186 - val_categorical_accuracy: 0.7757
# Epoch 10/50
# 79/79 [==============================] - 4s 54ms/step - loss: 0.0177 - categorical_accuracy: 0.7795 - val_loss: 0.0171 - val_categorical_accuracy: 0.7955
# Epoch 11/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0164 - categorical_accuracy: 0.8032 - val_loss: 0.0161 - val_categorical_accuracy: 0.8190
# Epoch 12/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0155 - categorical_accuracy: 0.8312 - val_loss: 0.0153 - val_categorical_accuracy: 0.8446
# Epoch 13/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0146 - categorical_accuracy: 0.8562 - val_loss: 0.0146 - val_categorical_accuracy: 0.8654
# Epoch 14/50
# 79/79 [==============================] - 4s 54ms/step - loss: 0.0140 - categorical_accuracy: 0.8751 - val_loss: 0.0140 - val_categorical_accuracy: 0.8867
# Epoch 15/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0135 - categorical_accuracy: 0.8929 - val_loss: 0.0135 - val_categorical_accuracy: 0.8997
# Epoch 16/50
# 79/79 [==============================] - 4s 56ms/step - loss: 0.0129 - categorical_accuracy: 0.9063 - val_loss: 0.0130 - val_categorical_accuracy: 0.9126
# Epoch 17/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0125 - categorical_accuracy: 0.9195 - val_loss: 0.0126 - val_categorical_accuracy: 0.9233
# Epoch 18/50
# 79/79 [==============================] - 4s 56ms/step - loss: 0.0120 - categorical_accuracy: 0.9288 - val_loss: 0.0122 - val_categorical_accuracy: 0.9311
# Epoch 19/50
# 79/79 [==============================] - 4s 54ms/step - loss: 0.0116 - categorical_accuracy: 0.9358 - val_loss: 0.0118 - val_categorical_accuracy: 0.9371
# Epoch 20/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0113 - categorical_accuracy: 0.9412 - val_loss: 0.0114 - val_categorical_accuracy: 0.9427
# Epoch 21/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0110 - categorical_accuracy: 0.9461 - val_loss: 0.0111 - val_categorical_accuracy: 0.9465
# Epoch 22/50
# 79/79 [==============================] - 4s 56ms/step - loss: 0.0107 - categorical_accuracy: 0.9492 - val_loss: 0.0109 - val_categorical_accuracy: 0.9495
# Epoch 23/50
# 79/79 [==============================] - 4s 56ms/step - loss: 0.0104 - categorical_accuracy: 0.9523 - val_loss: 0.0106 - val_categorical_accuracy: 0.9518
# Epoch 24/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0102 - categorical_accuracy: 0.9545 - val_loss: 0.0103 - val_categorical_accuracy: 0.9538
# Epoch 25/50
# 79/79 [==============================] - 4s 56ms/step - loss: 0.0099 - categorical_accuracy: 0.9565 - val_loss: 0.0101 - val_categorical_accuracy: 0.9553
# Epoch 26/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0096 - categorical_accuracy: 0.9580 - val_loss: 0.0099 - val_categorical_accuracy: 0.9565
# Epoch 27/50
# 79/79 [==============================] - 4s 56ms/step - loss: 0.0094 - categorical_accuracy: 0.9588 - val_loss: 0.0096 - val_categorical_accuracy: 0.9574
# Epoch 28/50
# 79/79 [==============================] - 4s 54ms/step - loss: 0.0092 - categorical_accuracy: 0.9595 - val_loss: 0.0094 - val_categorical_accuracy: 0.9581
# Epoch 29/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0091 - categorical_accuracy: 0.9598 - val_loss: 0.0092 - val_categorical_accuracy: 0.9586
# Epoch 30/50
# 79/79 [==============================] - 4s 56ms/step - loss: 0.0088 - categorical_accuracy: 0.9606 - val_loss: 0.0088 - val_categorical_accuracy: 0.9603
# Epoch 31/50
# 79/79 [==============================] - 4s 56ms/step - loss: 0.0084 - categorical_accuracy: 0.9630 - val_loss: 0.0085 - val_categorical_accuracy: 0.9619
# Epoch 32/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0081 - categorical_accuracy: 0.9641 - val_loss: 0.0083 - val_categorical_accuracy: 0.9622
# Epoch 33/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0080 - categorical_accuracy: 0.9641 - val_loss: 0.0083 - val_categorical_accuracy: 0.9625
# Epoch 34/50
# 79/79 [==============================] - 4s 54ms/step - loss: 0.0079 - categorical_accuracy: 0.9643 - val_loss: 0.0080 - val_categorical_accuracy: 0.9630
# Epoch 35/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0077 - categorical_accuracy: 0.9647 - val_loss: 0.0078 - val_categorical_accuracy: 0.9633
# Epoch 36/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0075 - categorical_accuracy: 0.9651 - val_loss: 0.0077 - val_categorical_accuracy: 0.9636
# Epoch 37/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0074 - categorical_accuracy: 0.9646 - val_loss: 0.0075 - val_categorical_accuracy: 0.9637
# Epoch 38/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0072 - categorical_accuracy: 0.9652 - val_loss: 0.0074 - val_categorical_accuracy: 0.9639
# Epoch 39/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0070 - categorical_accuracy: 0.9656 - val_loss: 0.0073 - val_categorical_accuracy: 0.9640
# Epoch 40/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0070 - categorical_accuracy: 0.9651 - val_loss: 0.0071 - val_categorical_accuracy: 0.9642
# Epoch 41/50
# 79/79 [==============================] - 4s 56ms/step - loss: 0.0068 - categorical_accuracy: 0.9657 - val_loss: 0.0070 - val_categorical_accuracy: 0.9643
# Epoch 42/50
# 79/79 [==============================] - 4s 56ms/step - loss: 0.0067 - categorical_accuracy: 0.9658 - val_loss: 0.0069 - val_categorical_accuracy: 0.9644
# Epoch 43/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0066 - categorical_accuracy: 0.9656 - val_loss: 0.0068 - val_categorical_accuracy: 0.9645
# Epoch 44/50
# 79/79 [==============================] - 4s 56ms/step - loss: 0.0065 - categorical_accuracy: 0.9659 - val_loss: 0.0067 - val_categorical_accuracy: 0.9646
# Epoch 45/50
# 79/79 [==============================] - 4s 56ms/step - loss: 0.0064 - categorical_accuracy: 0.9657 - val_loss: 0.0066 - val_categorical_accuracy: 0.9646
# Epoch 46/50
# 79/79 [==============================] - 4s 56ms/step - loss: 0.0063 - categorical_accuracy: 0.9663 - val_loss: 0.0065 - val_categorical_accuracy: 0.9647
# Epoch 47/50
# 79/79 [==============================] - 4s 54ms/step - loss: 0.0062 - categorical_accuracy: 0.9659 - val_loss: 0.0064 - val_categorical_accuracy: 0.9647
# Epoch 48/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0062 - categorical_accuracy: 0.9659 - val_loss: 0.0064 - val_categorical_accuracy: 0.9648
# Epoch 49/50
# 79/79 [==============================] - 4s 55ms/step - loss: 0.0061 - categorical_accuracy: 0.9662 - val_loss: 0.0063 - val_categorical_accuracy: 0.9648
# Epoch 50/50
# 79/79 [==============================] - 4s 54ms/step - loss: 0.0060 - categorical_accuracy: 0.9663 - val_loss: 0.0062 - val_categorical_accuracy: 0.9648

# %% [markdown]
# Let's plot the accuracy and the loss trends and check the reconstruction capability of the model by plotting the reconstruction of a test sample

# %%
def plot_categorical_accuracy(history):
  plt.figure(figsize=(10,6))
  plt.plot(history.epoch,history.history['categorical_accuracy'])
  plt.plot(history.epoch,history.history['val_categorical_accuracy'])
  plt.title('accuracy')

plot_loss(history)

plot_categorical_accuracy(history)

scores = sequence_autoencoder.evaluate(X_test_one_hot, X_test_one_hot, verbose=2)
print("%s: %.2f%%" % (sequence_autoencoder.metrics_names[1], scores[1]*100))
# Out:
# 40/40 - 0s - loss: 0.0061 - categorical_accuracy: 0.9657
# categorical_accuracy: 96.57%

# %%
decoded_text = sequence_autoencoder.predict(X_test_one_hot)
decode_index= np.argmax(decoded_text[500], axis=1)
input_text= np.argmax(X_test_one_hot[500], axis=1)

print(decode_review(input_text))
print(decode_review(decode_index))
# Out:
# than a <oov> <oov> that are <oov> in all of that time but that <oov> the <oov> is <oov> a very <oov> film in just about <oov> <oov> <oov> <oov> as some other <oov> have <oov> out it <oov> like <oov> <oov> of the film are <oov> <oov> there <oov> other <oov> <oov> <oov> are <oov> <oov> in the <oov> <oov> this is a really bad film that <oov> <oov> <oov> than its <oov> of <oov> <oov> i <oov> it <oov> out of <oov> and i <oov> <oov> very <oov>
# than a <oov> <oov> that are <oov> in all of that time but that <oov> the <oov> is <oov> a that <oov> film in just about <oov> <oov> <oov> <oov> as some other <oov> have <oov> out it <oov> like <oov> <oov> of the film are <oov> <oov> there <oov> other <oov> <oov> <oov> are <oov> <oov> in the <oov> <oov> this is a really of film that <oov> <oov> <oov> than film <oov> of <oov> <oov> i <oov> it <oov> out of <oov> and i <oov> <oov> the <oov>

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.7: Non-Linear Autoencoder for sequences
# **[TO COMPLETE]**: Replicate the code of the above exercise, but instead of using a simpleRNN with linear activation do the same  using  non-linear activation functions and using an LSTM layer. Choose the most appropriate non-linear function, and motivate your choice. Then discuss the results in relation to those obtained by the linear autoencoder for sequences.
#
# Hint: using a non-linear function also in the dense layer after the RNN/LSTM one will help to obtain better results. The choice of this function should be based on the type of output data.

# %% [markdown]
# By experimenting with a for loop:
# In the decoding layer, we can see that the results of the tanh activation function are always better than other functions.
# Using a tanh activation for the output layer and a linear one for the LSTM layer, we get 96% validation accuracy. Then we start experimenting with other functions for LSTM by applying a tanh function, which gives better results than a linear one, around 97%, sigmoid has very low accuracy, less than 20%, and ReLu performs even worse. In conclusion, tanh has the best performance for this type of input.

# %%
inputs = tf.keras.layers.Input(shape=(maxlen, num_words))
encoded = tf.keras.layers.LSTM(50, return_sequences=True, activation='tanh')(inputs)

decoded = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(num_words, activation='tanh'))(encoded)

sequence_autoencoder = tf.keras.models.Model(inputs, decoded)
encoder = tf.keras.models.Model(inputs, encoded)

sequence_autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=["CategoricalAccuracy"])

sequence_autoencoder.summary()

history = sequence_autoencoder.fit(X_train_one_hot, X_train_one_hot, epochs=50, batch_size=128, shuffle=True,
                                   validation_data=(X_valid_one_hot, X_valid_one_hot))
# Out:
# Model: "model_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_27 (InputLayer)        [(None, 90, 100)]         0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 90, 50)            30200
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 90, 100)           5100
# =================================================================
# Total params: 35,300
# Trainable params: 35,300
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 79/79 [==============================] - 31s 18ms/step - loss: 0.0685 - categorical_accuracy: 0.2889 - val_loss: 0.0377 - val_categorical_accuracy: 0.4951
# Epoch 2/50
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0359 - categorical_accuracy: 0.5029 - val_loss: 0.0328 - val_categorical_accuracy: 0.4969
# Epoch 3/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0318 - categorical_accuracy: 0.5041 - val_loss: 0.0306 - val_categorical_accuracy: 0.4984
# Epoch 4/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0295 - categorical_accuracy: 0.5065 - val_loss: 0.0283 - val_categorical_accuracy: 0.5007
# Epoch 5/50
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0279 - categorical_accuracy: 0.5080 - val_loss: 0.0292 - val_categorical_accuracy: 0.5050
# Epoch 6/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0280 - categorical_accuracy: 0.5156 - val_loss: 0.0259 - val_categorical_accuracy: 0.5102
# Epoch 7/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0253 - categorical_accuracy: 0.5210 - val_loss: 0.0245 - val_categorical_accuracy: 0.5592
# Epoch 8/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0240 - categorical_accuracy: 0.5717 - val_loss: 0.0228 - val_categorical_accuracy: 0.6393
# Epoch 9/50
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0223 - categorical_accuracy: 0.6910 - val_loss: 0.0213 - val_categorical_accuracy: 0.7986
# Epoch 10/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0208 - categorical_accuracy: 0.8190 - val_loss: 0.0200 - val_categorical_accuracy: 0.8596
# Epoch 11/50
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0196 - categorical_accuracy: 0.8714 - val_loss: 0.0187 - val_categorical_accuracy: 0.8911
# Epoch 12/50
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0182 - categorical_accuracy: 0.8968 - val_loss: 0.0176 - val_categorical_accuracy: 0.9026
# Epoch 13/50
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0172 - categorical_accuracy: 0.9051 - val_loss: 0.0166 - val_categorical_accuracy: 0.9070
# Epoch 14/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0163 - categorical_accuracy: 0.9093 - val_loss: 0.0159 - val_categorical_accuracy: 0.9111
# Epoch 15/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0156 - categorical_accuracy: 0.9133 - val_loss: 0.0152 - val_categorical_accuracy: 0.9142
# Epoch 16/50
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0150 - categorical_accuracy: 0.9155 - val_loss: 0.0147 - val_categorical_accuracy: 0.9154
# Epoch 17/50
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0145 - categorical_accuracy: 0.9168 - val_loss: 0.0143 - val_categorical_accuracy: 0.9165
# Epoch 18/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0141 - categorical_accuracy: 0.9180 - val_loss: 0.0140 - val_categorical_accuracy: 0.9172
# Epoch 19/50
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0139 - categorical_accuracy: 0.9181 - val_loss: 0.0138 - val_categorical_accuracy: 0.9176
# Epoch 20/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0136 - categorical_accuracy: 0.9182 - val_loss: 0.0135 - val_categorical_accuracy: 0.9181
# Epoch 21/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0135 - categorical_accuracy: 0.9184 - val_loss: 0.0133 - val_categorical_accuracy: 0.9183
# Epoch 22/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0132 - categorical_accuracy: 0.9193 - val_loss: 0.0132 - val_categorical_accuracy: 0.9185
# Epoch 23/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0130 - categorical_accuracy: 0.9194 - val_loss: 0.0130 - val_categorical_accuracy: 0.9189
# Epoch 24/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0129 - categorical_accuracy: 0.9194 - val_loss: 0.0129 - val_categorical_accuracy: 0.9189
# Epoch 25/50
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0128 - categorical_accuracy: 0.9193 - val_loss: 0.0128 - val_categorical_accuracy: 0.9192
# Epoch 26/50
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0127 - categorical_accuracy: 0.9197 - val_loss: 0.0127 - val_categorical_accuracy: 0.9197
# Epoch 27/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0127 - categorical_accuracy: 0.9201 - val_loss: 0.0127 - val_categorical_accuracy: 0.9201
# Epoch 28/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0126 - categorical_accuracy: 0.9207 - val_loss: 0.0126 - val_categorical_accuracy: 0.9202
# Epoch 29/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0126 - categorical_accuracy: 0.9204 - val_loss: 0.0125 - val_categorical_accuracy: 0.9204
# Epoch 30/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0124 - categorical_accuracy: 0.9213 - val_loss: 0.0125 - val_categorical_accuracy: 0.9207
# Epoch 31/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0124 - categorical_accuracy: 0.9212 - val_loss: 0.0124 - val_categorical_accuracy: 0.9218
# Epoch 32/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0123 - categorical_accuracy: 0.9227 - val_loss: 0.0124 - val_categorical_accuracy: 0.9220
# Epoch 33/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0122 - categorical_accuracy: 0.9230 - val_loss: 0.0123 - val_categorical_accuracy: 0.9221
# Epoch 34/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0122 - categorical_accuracy: 0.9230 - val_loss: 0.0123 - val_categorical_accuracy: 0.9222
# Epoch 35/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0122 - categorical_accuracy: 0.9229 - val_loss: 0.0123 - val_categorical_accuracy: 0.9223
# Epoch 36/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0121 - categorical_accuracy: 0.9233 - val_loss: 0.0122 - val_categorical_accuracy: 0.9225
# Epoch 37/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0122 - categorical_accuracy: 0.9228 - val_loss: 0.0122 - val_categorical_accuracy: 0.9228
# Epoch 38/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0121 - categorical_accuracy: 0.9238 - val_loss: 0.0122 - val_categorical_accuracy: 0.9230
# Epoch 39/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0121 - categorical_accuracy: 0.9236 - val_loss: 0.0122 - val_categorical_accuracy: 0.9231
# Epoch 40/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0120 - categorical_accuracy: 0.9240 - val_loss: 0.0121 - val_categorical_accuracy: 0.9234
# Epoch 41/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0120 - categorical_accuracy: 0.9241 - val_loss: 0.0121 - val_categorical_accuracy: 0.9234
# Epoch 42/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0121 - categorical_accuracy: 0.9238 - val_loss: 0.0121 - val_categorical_accuracy: 0.9235
# Epoch 43/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0121 - categorical_accuracy: 0.9236 - val_loss: 0.0121 - val_categorical_accuracy: 0.9235
# Epoch 44/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0120 - categorical_accuracy: 0.9242 - val_loss: 0.0121 - val_categorical_accuracy: 0.9235
# Epoch 45/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0120 - categorical_accuracy: 0.9238 - val_loss: 0.0120 - val_categorical_accuracy: 0.9235
# Epoch 46/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0120 - categorical_accuracy: 0.9239 - val_loss: 0.0120 - val_categorical_accuracy: 0.9236
# Epoch 47/50
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0119 - categorical_accuracy: 0.9243 - val_loss: 0.0120 - val_categorical_accuracy: 0.9236
# Epoch 48/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0120 - categorical_accuracy: 0.9239 - val_loss: 0.0120 - val_categorical_accuracy: 0.9236
# Epoch 49/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0119 - categorical_accuracy: 0.9244 - val_loss: 0.0120 - val_categorical_accuracy: 0.9236
# Epoch 50/50
# 79/79 [==============================] - 1s 13ms/step - loss: 0.0119 - categorical_accuracy: 0.9240 - val_loss: 0.0120 - val_categorical_accuracy: 0.9236

# %%
plot_loss(history)

plot_categorical_accuracy(history)

scores = sequence_autoencoder.evaluate(X_test_one_hot, X_test_one_hot, verbose=2)
print("%s: %.2f%%" % (sequence_autoencoder.metrics_names[1], scores[1]*100))
# Out:
# 40/40 - 0s - loss: 0.0120 - categorical_accuracy: 0.9237
# categorical_accuracy: 92.37%

# %%
decoded_text = sequence_autoencoder.predict(X_test_one_hot)
decode_index= np.argmax(decoded_text[500], axis=1)
input_text= np.argmax(X_test_one_hot[500], axis=1)

print(decode_review(input_text))
print(decode_review(decode_index))
# Out:
# than a <oov> <oov> that are <oov> in all of that time but that <oov> the <oov> is <oov> a very <oov> film in just about <oov> <oov> <oov> <oov> as some other <oov> have <oov> out it <oov> like <oov> <oov> of the film are <oov> <oov> there <oov> other <oov> <oov> <oov> are <oov> <oov> in the <oov> <oov> this is a really bad film that <oov> <oov> <oov> than its <oov> of <oov> <oov> i <oov> it <oov> out of <oov> and i <oov> <oov> very <oov>
# than a <oov> <oov> that a <oov> in all most that <oov> but that <oov> the <oov> is <oov> a very <oov> film in just about <oov> <oov> <oov> <oov> as some other <oov> have <oov> out it <oov> like <oov> <oov> most the film much <oov> <oov> there <oov> other <oov> <oov> <oov> their <oov> <oov> in the <oov> <oov> this is a <oov> bad film that <oov> <oov> <oov> than its <oov> most <oov> <oov> i <oov> it <oov> out their <oov> and i <oov> <oov> very <oov>
